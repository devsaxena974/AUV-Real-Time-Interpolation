# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('C:/College/EdgeComputing/build/Debug/grid_large.csv', header=None)
df
# Out:
#           0         1         2         3         4         5         6     \
# 0    -1015.000 -1015.100 -1015.200 -1015.300 -1015.400 -1015.500 -1015.600
# 1    -1015.000 -1015.100 -1015.200 -1015.300 -1015.400 -1015.500 -1015.600
# 2    -1015.000 -1015.100 -1015.200 -1015.300 -1015.400 -1015.500 -1015.600
# 3    -1014.990 -1015.090 -1015.190 -1015.290 -1015.390 -1015.490 -1015.590
# 4    -1014.990 -1015.090 -1015.190 -1015.290 -1015.390 -1015.490 -1015.590
# ...        ...       ...       ...       ...       ...       ...       ...
# 1595  -985.437  -985.537  -985.637  -985.737  -985.837  -985.937  -986.037
# 1596  -985.474  -985.574  -985.674  -985.774  -985.874  -985.974  -986.074
# 1597  -985.512  -985.612  -985.712  -985.812  -985.912  -986.012  -986.112
# 1598  -985.552  -985.652  -985.752  -985.852  -985.952  -986.051  -986.151
# 1599  -985.593  -985.693  -985.793  -985.893  -985.993  -986.092  -986.192
#
# ...

# %%
new_df = pd.read_csv('C:/College/EdgeComputing/build/Debug/expanded_interpolated_grid.csv', header=None)
new_df
# Out:
#           0         1         2         3         4         5         6     \
# 0    -1015.000 -1015.050 -1015.100 -1015.150 -1015.200 -1015.250 -1015.300
# 1    -1015.000 -1015.050 -1015.100 -1015.150 -1015.200 -1015.250 -1015.300
# 2    -1015.000 -1015.050 -1015.100 -1015.150 -1015.200 -1015.250 -1015.300
# 3    -1015.000 -1015.050 -1015.100 -1015.150 -1015.200 -1015.250 -1015.300
# 4    -1015.000 -1015.050 -1015.100 -1015.150 -1015.200 -1015.250 -1015.300
# ...        ...       ...       ...       ...       ...       ...       ...
# 3194  -985.512  -985.562  -985.612  -985.662  -985.712  -985.762  -985.812
# 3195  -985.532  -985.582  -985.632  -985.682  -985.732  -985.782  -985.832
# 3196  -985.552  -985.602  -985.652  -985.702  -985.752  -985.802  -985.852
# 3197  -985.572  -985.623  -985.673  -985.723  -985.772  -985.822  -985.872
# 3198  -985.593  -985.643  -985.693  -985.743  -985.793  -985.843  -985.893
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
# Convert the DataFrame to a NumPy array.
elevation_matrix = df.values

# Create the heatmap.
plt.figure(figsize=(8, 6))
plt.imshow(elevation_matrix, cmap='viridis', origin='lower')
plt.colorbar(label='Elevation (m)')
plt.title("Bathymetry Heatmap")
plt.xlabel("Grid X")
plt.ylabel("Grid Y")
plt.show()

# %%
# Convert the DataFrame to a NumPy array.
new_elevation_matrix = new_df.values

# Create the heatmap.
plt.clf()
plt.figure(figsize=(8, 6))
plt.imshow(new_elevation_matrix, cmap='viridis', origin='lower')
plt.colorbar(label='Interpolated Elevations (m)')
plt.title("Bathymetry Heatmap")
plt.xlabel("Grid X")
plt.ylabel("Grid Y")
plt.show()
