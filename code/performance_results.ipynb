# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
results = pd.read_csv(r'..\results\TestingResults1.csv')
results
# Out:
#     Machine InterpolationType GridType  BatchSize  Time  RemovalFraction  \
# 0       CPU          Bilinear        A       1000     0              NaN
# 1       CPU             Cubic        A       1000     0              NaN
# 2       CPU           Kriging        A       1000     6              NaN
# 3       GPU          Bilinear        A       1000    13              NaN
# 4       GPU             Cubic        A       1000    40              NaN
# ..      ...               ...      ...        ...   ...              ...
# 379     CPU             Cubic        B     500688  1373              0.1
# 380     CPU           Kriging        B     500688  1527              0.1
# 381     GPU          Bilinear        B     500688   110              0.1
# 382     GPU             Cubic        B     500688   450              0.1
# 383     GPU           Kriging        B     500688   729              0.1
#
#          MAE     RMSE  Max Error
# 0        NaN      NaN        NaN
# 1        NaN      NaN        NaN
# 2        NaN      NaN        NaN
# 3        NaN      NaN        NaN
# 4        NaN      NaN        NaN
# ..       ...      ...        ...
# 379  6.29409  15.0865    509.000
# 380  4.86911  11.0187    342.524
# 381  6.76993  16.0945    493.000
# 382  6.29409  15.0865    509.000
# 383  4.86911  11.0187    342.524
#
# [384 rows x 9 columns]

# %% [markdown]
# ## Performance Metrics

# %% [markdown]
# ### Grid A

# %% [markdown]
# Calculates the average time in ms that both the CPU and GPU took to run
#     on each interpolation type, for each batch size of data
#
# The batch sizes are: 1000, 5000, 100000, 500000, 100000, 1000000, 5000000

# %%
grid_a_results = results.loc[results['GridType'] == 'A']
grid_a_results
# Out:
#     Machine InterpolationType GridType  BatchSize   Time  RemovalFraction  \
# 0       CPU          Bilinear        A       1000      0              NaN
# 1       CPU             Cubic        A       1000      0              NaN
# 2       CPU           Kriging        A       1000      6              NaN
# 3       GPU          Bilinear        A       1000     13              NaN
# 4       GPU             Cubic        A       1000     40              NaN
# ..      ...               ...      ...        ...    ...              ...
# 247     CPU             Cubic        A    5000000   2901              NaN
# 248     CPU           Kriging        A    5000000  14942              NaN
# 249     GPU          Bilinear        A    5000000    462              NaN
# 250     GPU             Cubic        A    5000000    420              NaN
# 251     GPU           Kriging        A    5000000    561              NaN
#
#      MAE  RMSE  Max Error
# 0    NaN   NaN        NaN
# 1    NaN   NaN        NaN
# 2    NaN   NaN        NaN
# 3    NaN   NaN        NaN
# 4    NaN   NaN        NaN
# ..   ...   ...        ...
# 247  NaN   NaN        NaN
# 248  NaN   NaN        NaN
# 249  NaN   NaN        NaN
# 250  NaN   NaN        NaN
# 251  NaN   NaN        NaN
#
# [210 rows x 9 columns]

# %%
# separate into df's by batch size
sizes = grid_a_results['BatchSize'].unique()
sizes
# Out:
# array([   1000,    5000,   10000,   50000,  100000, 1000000, 5000000],
#       dtype=int64)

# %%
interp_types = ['Bilinear', 'Cubic', 'Kriging']
machines = ['CPU', 'GPU']

# Dict to store performance for each batch size
performance_a = {
    'CPU Bilinear': [],
    'GPU Bilinear': [],
    'CPU Cubic': [],
    'GPU Cubic': [],
    'CPU Kriging': [],
    'GPU Kriging': []
}

for size in sizes:
    # subset the appropriate batch
    batch = grid_a_results.loc[grid_a_results['BatchSize'] == size]

    for interp in interp_types:
        for machine in machines:
            # 1) Get all entries for machine and interpolation type from larger set
            subset = batch.loc[(batch['Machine'] == machine) & (batch['InterpolationType'] == interp)]
            
            # 2) Sum over all times and divide by length to get average
            average = np.mean(subset['Time'].values)

            key_string = machine + " " + interp
            performance_a[key_string].append(average)

for key in performance_a.keys():
    print(key, performance_a[key])
# Out:
# CPU Bilinear [0.2, 0.8, 1.4, 8.8, 15.4, 170.8, 830.6]
# GPU Bilinear [8.6, 1.6, 2.4, 6.8, 13.2, 116.8, 684.6]
# CPU Cubic [0.0, 3.4, 7.0, 33.6, 74.0, 678.6, 3404.4]
# GPU Cubic [27.4, 2.6, 6.0, 27.8, 53.2, 486.6, 2393.2]
# CPU Kriging [4.0, 18.0, 35.8, 165.6, 333.4, 3212.4, 16252.2]
# GPU Kriging [4.6, 5.8, 11.4, 47.6, 93.0, 903.2, 4484.2]

# %% [markdown]
# ### Grid B

# %% [markdown]
# Calculates average performance times (ms) and average errors for CPU and GPU
#     performance on each interpolation type based on:
#
# - Region (Mid-Atlantic Ridge, East-Pacific Rise, Mariana Trench, Kerguelen Plateau)
# - Removal Fraction -> percentage of data randomly masked from the original grid to imitate real-life        applications

# %%
grid_b_results = results.loc[results['GridType'] == 'B']
grid_b_results
# Out:
#     Machine InterpolationType GridType  BatchSize  Time  RemovalFraction  \
# 126     CPU          Bilinear        B       8101     1             0.01
# 127     CPU             Cubic        B       8101    21             0.01
# 128     CPU           Kriging        B       8101    23             0.01
# 129     GPU          Bilinear        B       8101   148             0.01
# 130     GPU             Cubic        B       8101    47             0.01
# ..      ...               ...      ...        ...   ...              ...
# 379     CPU             Cubic        B     500688  1373             0.10
# 380     CPU           Kriging        B     500688  1527             0.10
# 381     GPU          Bilinear        B     500688   110             0.10
# 382     GPU             Cubic        B     500688   450             0.10
# 383     GPU           Kriging        B     500688   729             0.10
#
#          MAE      RMSE  Max Error
# 126  3.54526   6.76434    196.000
# 127  3.91214   7.12105    156.500
# 128  3.37423   5.80733    168.544
# 129  3.54526   6.76434    196.000
# 130  3.91214   7.12105    156.500
# ..       ...       ...        ...
# 379  6.29409  15.08650    509.000
# 380  4.86911  11.01870    342.524
# 381  6.76993  16.09450    493.000
# 382  6.29409  15.08650    509.000
# 383  4.86911  11.01870    342.524
#
# [174 rows x 9 columns]

# %%
sizes = grid_b_results['BatchSize'].unique()
sizes
# Out:
# array([  8101,  40507,  81015, 121523, 162031,   1303,  14428,   9321,
#         46609,  50068, 250344,  93218, 500688], dtype=int64)

# %%
fracs = grid_b_results['RemovalFraction'].unique()
fracs
# Out:
# array([0.01, 0.05, 0.1 , 0.15, 0.2 ])

# %% [markdown]
# FIX LATER: Need to keep track of which rows correspond to which region's data
#     Doing it all manually right now (very bad)

# %% [markdown]
# ## Tectonically Active Zones

# %% [markdown]
# ### Mid-Atlantic Ridge
# #### Removal Fraction = 0.01
# TestingResults1 - rows 278-289

# %%
# indexes are a bit off, go low-row-index - 2 and high-row-index - 1
mid_atlantic = results.iloc[276:288]
mid_atlantic
# Out:
#     Machine InterpolationType GridType  BatchSize  Time  RemovalFraction  \
# 276     CPU          Bilinear        B       1303     0             0.01
# 277     CPU             Cubic        B       1303     3             0.01
# 278     CPU           Kriging        B       1303     4             0.01
# 279     GPU          Bilinear        B       1303    16             0.01
# 280     GPU             Cubic        B       1303    38             0.01
# 281     GPU           Kriging        B       1303     7             0.01
# 282     CPU          Bilinear        B       1303     0             0.01
# 283     CPU             Cubic        B       1303     4             0.01
# 284     CPU           Kriging        B       1303     3             0.01
# 285     GPU          Bilinear        B       1303    10             0.01
# 286     GPU             Cubic        B       1303    38             0.01
# 287     GPU           Kriging        B       1303     5             0.01
#
#          MAE     RMSE  Max Error
# 276  16.8584  26.5357    165.667
# 277  15.7884  27.2985    212.750
# 278  13.4503  22.6796    194.635
# 279  16.8584  26.5357    165.667
# 280  15.7884  27.2985    212.750
# 281  13.4503  22.6796    194.635
# 282  16.8584  26.5357    165.667
# 283  15.7884  27.2985    212.750
# 284  13.4503  22.6796    194.635
# 285  16.8584  26.5357    165.667
# 286  15.7884  27.2985    212.750
# 287  13.4503  22.6796    194.635

# %%
interp_types = ['Bilinear', 'Cubic', 'Kriging']
machines = ['CPU', 'GPU']

perf = {
    'CPU Bilinear': [],
    'GPU Bilinear': [],
    'CPU Cubic': [],
    'GPU Cubic': [],
    'CPU Kriging': [],
    'GPU Kriging': []
}

for interp in interp_types:
    for machine in machines:
        key_string = machine + " " + interp
        # 1) Get all entries for machine and interpolation type from larger set
        subset = mid_atlantic.loc[(mid_atlantic['Machine'] == machine) & (mid_atlantic['InterpolationType'] == interp)]
        
        # 2) Sum over all times and divide by length to get average
        average = np.mean(subset['Time'].values)

        perf[key_string].append(average)

        # 3) Average out the Mean Absolute Error (MAE's)
        mae_avg = np.mean(subset['MAE'].values)

        perf[key_string].append(mae_avg)

        # 4) Average out the Root Mean Squared Error (RMSE's)
        rmse_avg = np.mean(subset['RMSE'].values)

        perf[key_string].append(rmse_avg)

        # 5) Average out the max error's
        max_err_avg = np.mean(subset['Max Error'].values)

        perf[key_string].append(max_err_avg)

for key in perf.keys():
    print(key, perf[key])
# Out:
# CPU Bilinear [0.0, 16.8584, 26.5357, 165.667]
# GPU Bilinear [13.0, 16.8584, 26.5357, 165.667]
# CPU Cubic [3.5, 15.7884, 27.2985, 212.75]
# GPU Cubic [38.0, 15.7884, 27.2985, 212.75]
# CPU Kriging [3.5, 13.4503, 22.6796, 194.635]
# GPU Kriging [6.0, 13.4503, 22.6796, 194.635]

# %% [markdown]
# ### East Pacific Rise
# #### Removal Fraction = 0.01
# TestingResults1 - rows 290-301

# %%
# indexes are a bit off, go low-row-index - 2 and high-row-index - 1
east_pacific = results.iloc[288:300]
east_pacific
# Out:
#     Machine InterpolationType GridType  BatchSize  Time  RemovalFraction  \
# 288     CPU          Bilinear        B      14428     2             0.01
# 289     CPU             Cubic        B      14428    38             0.01
# 290     CPU           Kriging        B      14428    42             0.01
# 291     GPU          Bilinear        B      14428    16             0.01
# 292     GPU             Cubic        B      14428    52             0.01
# 293     GPU           Kriging        B      14428    24             0.01
# 294     CPU          Bilinear        B      14428     3             0.01
# 295     CPU             Cubic        B      14428    49             0.01
# 296     CPU           Kriging        B      14428    45             0.01
# 297     GPU          Bilinear        B      14428    13             0.01
# 298     GPU             Cubic        B      14428    52             0.01
# 299     GPU           Kriging        B      14428    23             0.01
#
#          MAE     RMSE  Max Error
# 288  14.4228  24.8556    305.667
# 289  14.4862  25.9785    363.250
# 290  11.1512  19.4132    453.267
# 291  14.4228  24.8556    305.667
# 292  14.4862  25.9785    363.250
# 293  11.1512  19.4132    453.267
# 294  14.4228  24.8556    305.667
# 295  14.4862  25.9785    363.250
# 296  11.1512  19.4132    453.267
# 297  14.4228  24.8556    305.667
# 298  14.4862  25.9785    363.250
# 299  11.1512  19.4132    453.267

# %%
interp_types = ['Bilinear', 'Cubic', 'Kriging']
machines = ['CPU', 'GPU']

perf = {
    'CPU Bilinear': [],
    'GPU Bilinear': [],
    'CPU Cubic': [],
    'GPU Cubic': [],
    'CPU Kriging': [],
    'GPU Kriging': []
}

for interp in interp_types:
    for machine in machines:
        key_string = machine + " " + interp
        # 1) Get all entries for machine and interpolation type from larger set
        subset = east_pacific.loc[(east_pacific['Machine'] == machine) & (east_pacific['InterpolationType'] == interp)]
        
        # 2) Sum over all times and divide by length to get average
        average = np.mean(subset['Time'].values)

        perf[key_string].append(average)

        # 3) Average out the Mean Absolute Error (MAE's)
        mae_avg = np.mean(subset['MAE'].values)

        perf[key_string].append(mae_avg)

        # 4) Average out the Root Mean Squared Error (RMSE's)
        rmse_avg = np.mean(subset['RMSE'].values)

        perf[key_string].append(rmse_avg)

        # 5) Average out the max error's
        max_err_avg = np.mean(subset['Max Error'].values)

        perf[key_string].append(max_err_avg)

for key in perf.keys():
    print(key, perf[key])
# Out:
# CPU Bilinear [2.5, 14.4228, 24.8556, 305.667]
# GPU Bilinear [14.5, 14.4228, 24.8556, 305.667]
# CPU Cubic [43.5, 14.4862, 25.9785, 363.25]
# GPU Cubic [52.0, 14.4862, 25.9785, 363.25]
# CPU Kriging [43.5, 11.1512, 19.4132, 453.267]
# GPU Kriging [23.5, 11.1512, 19.4132, 453.267]

# %% [markdown]
# ### Mariana Trench
# #### Removal Fraction = 0.01
# TestingResults1 - rows 302-313

# %%
# indexes are a bit off, go low-row-index - 2 and high-row-index - 1
mariana001 = results.iloc[300:312]
mariana001
# Out:
#     Machine InterpolationType GridType  BatchSize  Time  RemovalFraction  \
# 300     CPU          Bilinear        B       9321     1             0.01
# 301     CPU             Cubic        B       9321    24             0.01
# 302     CPU           Kriging        B       9321    26             0.01
# 303     GPU          Bilinear        B       9321    15             0.01
# 304     GPU             Cubic        B       9321    48             0.01
# 305     GPU           Kriging        B       9321    19             0.01
# 306     CPU          Bilinear        B       9321     1             0.01
# 307     CPU             Cubic        B       9321    24             0.01
# 308     CPU           Kriging        B       9321    25             0.01
# 309     GPU          Bilinear        B       9321    12             0.01
# 310     GPU             Cubic        B       9321    48             0.01
# 311     GPU           Kriging        B       9321    19             0.01
#
#          MAE     RMSE  Max Error
# 300  33.5012  49.6573    488.667
# 301  36.6279  58.1008    487.500
# 302  28.8211  42.9440    303.626
# 303  33.5012  49.6573    488.667
# 304  36.6279  58.1008    487.500
# 305  28.8211  42.9440    303.626
# 306  33.5012  49.6573    488.667
# 307  36.6279  58.1008    487.500
# 308  28.8211  42.9440    303.626
# 309  33.5012  49.6573    488.667
# 310  36.6279  58.1008    487.500
# 311  28.8211  42.9440    303.626

# %%
interp_types = ['Bilinear', 'Cubic', 'Kriging']
machines = ['CPU', 'GPU']

perf = {
    'CPU Bilinear': [],
    'GPU Bilinear': [],
    'CPU Cubic': [],
    'GPU Cubic': [],
    'CPU Kriging': [],
    'GPU Kriging': []
}

for interp in interp_types:
    for machine in machines:
        key_string = machine + " " + interp
        # 1) Get all entries for machine and interpolation type from larger set
        subset = mariana001.loc[(mariana001['Machine'] == machine) & (mariana001['InterpolationType'] == interp)]
        
        # 2) Sum over all times and divide by length to get average
        average = np.mean(subset['Time'].values)

        perf[key_string].append(average)

        # 3) Average out the Mean Absolute Error (MAE's)
        mae_avg = np.mean(subset['MAE'].values)

        perf[key_string].append(mae_avg)

        # 4) Average out the Root Mean Squared Error (RMSE's)
        rmse_avg = np.mean(subset['RMSE'].values)

        perf[key_string].append(rmse_avg)

        # 5) Average out the max error's
        max_err_avg = np.mean(subset['Max Error'].values)

        perf[key_string].append(max_err_avg)

for key in perf.keys():
    print(key, perf[key])
# Out:
# CPU Bilinear [1.0, 33.5012, 49.6573, 488.667]
# GPU Bilinear [13.5, 33.5012, 49.6573, 488.667]
# CPU Cubic [24.0, 36.6279, 58.1008, 487.5]
# GPU Cubic [48.0, 36.6279, 58.1008, 487.5]
# CPU Kriging [25.5, 28.8211, 42.944, 303.626]
# GPU Kriging [19.0, 28.8211, 42.944, 303.626]

# %% [markdown]
# #### Removal Fraction = 0.05
# TestingResults1 - rows 314-325

# %%
# indexes are a bit off, go low-row-index - 2 and high-row-index - 1
mariana005 = results.iloc[312:324]
mariana005
# Out:
#     Machine InterpolationType GridType  BatchSize  Time  RemovalFraction  \
# 312     CPU          Bilinear        B      46609     6             0.05
# 313     CPU             Cubic        B      46609   118             0.05
# 314     CPU           Kriging        B      46609   143             0.05
# 315     GPU          Bilinear        B      46609    19             0.05
# 316     GPU             Cubic        B      46609    81             0.05
# 317     GPU           Kriging        B      46609    72             0.05
# 318     CPU          Bilinear        B      46609    12             0.05
# 319     CPU             Cubic        B      46609   136             0.05
# 320     CPU           Kriging        B      46609   140             0.05
# 321     GPU          Bilinear        B      46609    18             0.05
# 322     GPU             Cubic        B      46609    80             0.05
# 323     GPU           Kriging        B      46609    73             0.05
#
#          MAE     RMSE  Max Error
# 312  33.5738  50.5098    693.333
# 313  35.7862  57.7545    755.000
# 314  28.0409  42.8661   1102.080
# 315  33.5738  50.5098    693.333
# 316  35.7862  57.7545    755.000
# 317  28.0409  42.8661   1102.080
# 318  33.5738  50.5098    693.333
# 319  35.7862  57.7545    755.000
# 320  28.0409  42.8661   1102.080
# 321  33.5738  50.5098    693.333
# 322  35.7862  57.7545    755.000
# 323  28.0409  42.8661   1102.080

# %%
interp_types = ['Bilinear', 'Cubic', 'Kriging']
machines = ['CPU', 'GPU']

perf = {
    'CPU Bilinear': [],
    'GPU Bilinear': [],
    'CPU Cubic': [],
    'GPU Cubic': [],
    'CPU Kriging': [],
    'GPU Kriging': []
}

for interp in interp_types:
    for machine in machines:
        key_string = machine + " " + interp
        # 1) Get all entries for machine and interpolation type from larger set
        subset = mariana005.loc[(mariana005['Machine'] == machine) & (mariana005['InterpolationType'] == interp)]
        
        # 2) Sum over all times and divide by length to get average
        average = np.mean(subset['Time'].values)

        perf[key_string].append(average)

        # 3) Average out the Mean Absolute Error (MAE's)
        mae_avg = np.mean(subset['MAE'].values)

        perf[key_string].append(mae_avg)

        # 4) Average out the Root Mean Squared Error (RMSE's)
        rmse_avg = np.mean(subset['RMSE'].values)

        perf[key_string].append(rmse_avg)

        # 5) Average out the max error's
        max_err_avg = np.mean(subset['Max Error'].values)

        perf[key_string].append(max_err_avg)

for key in perf.keys():
    print(key, perf[key])
# Out:
# CPU Bilinear [9.0, 33.5738, 50.5098, 693.333]
# GPU Bilinear [18.5, 33.5738, 50.5098, 693.333]
# CPU Cubic [127.0, 35.7862, 57.7545, 755.0]
# GPU Cubic [80.5, 35.7862, 57.7545, 755.0]
# CPU Kriging [141.5, 28.0409, 42.8661, 1102.08]
# GPU Kriging [72.5, 28.0409, 42.8661, 1102.08]

# %% [markdown]
# #### Removal Fraction = 0.10
# TestingResults1 - rows 350-367

# %%
# indexes are a bit off, go low-row-index - 2 and high-row-index - 1
mariana010 = results.iloc[348:366]
mariana010
# Out:
#     Machine InterpolationType GridType  BatchSize  Time  RemovalFraction  \
# 348     CPU          Bilinear        B      93218    12              0.1
# 349     CPU             Cubic        B      93218   238              0.1
# 350     CPU           Kriging        B      93218   264              0.1
# 351     GPU          Bilinear        B      93218    34              0.1
# 352     GPU             Cubic        B      93218   122              0.1
# 353     GPU           Kriging        B      93218   150              0.1
# 354     CPU          Bilinear        B      93218    13              0.1
# 355     CPU             Cubic        B      93218   248              0.1
# 356     CPU           Kriging        B      93218   281              0.1
# 357     GPU          Bilinear        B      93218    30              0.1
# 358     GPU             Cubic        B      93218   122              0.1
# 359     GPU           Kriging        B      93218   149              0.1
# 360     CPU          Bilinear        B      93218    14              0.1
# 361     CPU             Cubic        B      93218   271              0.1
# 362     CPU           Kriging        B      93218   293              0.1
# 363     GPU          Bilinear        B      93218    30              0.1
# 364     GPU             Cubic        B      93218   125              0.1
# 365     GPU           Kriging        B      93218   149              0.1
#
#          MAE     RMSE  Max Error
# 348  33.7618  50.8976    693.333
# 349  35.7872  57.7101    755.000
# 350  27.7166  42.3636   1102.080
# 351  33.7618  50.8976    693.333
# 352  35.7872  57.7101    755.000
# 353  27.7166  42.3636   1102.080
# 354  33.7618  50.8976    693.333
# 355  35.7872  57.7101    755.000
# 356  27.7166  42.3636   1102.080
# 357  33.7618  50.8976    693.333
# 358  35.7872  57.7101    755.000
# 359  27.7166  42.3636   1102.080
# 360  33.7618  50.8976    693.333
# 361  35.7872  57.7101    755.000
# 362  27.7166  42.3636   1102.080
# 363  33.7618  50.8976    693.333
# 364  35.7872  57.7101    755.000
# 365  27.7166  42.3636   1102.080

# %%
interp_types = ['Bilinear', 'Cubic', 'Kriging']
machines = ['CPU', 'GPU']

perf = {
    'CPU Bilinear': [],
    'GPU Bilinear': [],
    'CPU Cubic': [],
    'GPU Cubic': [],
    'CPU Kriging': [],
    'GPU Kriging': []
}

for interp in interp_types:
    for machine in machines:
        key_string = machine + " " + interp
        # 1) Get all entries for machine and interpolation type from larger set
        subset = mariana010.loc[(mariana010['Machine'] == machine) & (mariana010['InterpolationType'] == interp)]
        
        # 2) Sum over all times and divide by length to get average
        average = np.mean(subset['Time'].values)

        perf[key_string].append(average)

        # 3) Average out the Mean Absolute Error (MAE's)
        mae_avg = np.mean(subset['MAE'].values)

        perf[key_string].append(mae_avg)

        # 4) Average out the Root Mean Squared Error (RMSE's)
        rmse_avg = np.mean(subset['RMSE'].values)

        perf[key_string].append(rmse_avg)

        # 5) Average out the max error's
        max_err_avg = np.mean(subset['Max Error'].values)

        perf[key_string].append(max_err_avg)

for key in perf.keys():
    print(key, perf[key])
# Out:
# CPU Bilinear [13.0, 33.7618, 50.89759999999999, 693.333]
# GPU Bilinear [31.333333333333332, 33.7618, 50.89759999999999, 693.333]
# CPU Cubic [252.33333333333334, 35.7872, 57.71009999999999, 755.0]
# GPU Cubic [123.0, 35.7872, 57.71009999999999, 755.0]
# CPU Kriging [279.3333333333333, 27.7166, 42.3636, 1102.08]
# GPU Kriging [149.33333333333334, 27.7166, 42.3636, 1102.08]

# %% [markdown]
# ## Oceanic Plateaus

# %% [markdown]
# ### Kerguelen Plateau
# #### Removal Fraction = 0.01
# TestingResults1 - rows 326-337

# %%
# indexes are a bit off, go low-row-index - 2 and high-row-index - 1
kerguelen001 = results.iloc[324:336]
kerguelen001
# Out:
#     Machine InterpolationType GridType  BatchSize  Time  RemovalFraction  \
# 324     CPU          Bilinear        B      50068     9             0.01
# 325     CPU             Cubic        B      50068   133             0.01
# 326     CPU           Kriging        B      50068   158             0.01
# 327     GPU          Bilinear        B      50068    25             0.01
# 328     GPU             Cubic        B      50068    85             0.01
# 329     GPU           Kriging        B      50068    78             0.01
# 330     CPU          Bilinear        B      50068     9             0.01
# 331     CPU             Cubic        B      50068   146             0.01
# 332     CPU           Kriging        B      50068   150             0.01
# 333     GPU          Bilinear        B      50068    20             0.01
# 334     GPU             Cubic        B      50068    82             0.01
# 335     GPU           Kriging        B      50068    73             0.01
#
#          MAE     RMSE  Max Error
# 324  6.67990  15.5192    351.000
# 325  6.27658  14.8250    473.250
# 326  5.03055  11.3488    304.221
# 327  6.67990  15.5192    351.000
# 328  6.27658  14.8250    473.250
# 329  5.03055  11.3488    304.221
# 330  6.67990  15.5192    351.000
# 331  6.27658  14.8250    473.250
# 332  5.03055  11.3488    304.221
# 333  6.67990  15.5192    351.000
# 334  6.27658  14.8250    473.250
# 335  5.03055  11.3488    304.221

# %%
interp_types = ['Bilinear', 'Cubic', 'Kriging']
machines = ['CPU', 'GPU']

perf = {
    'CPU Bilinear': [],
    'GPU Bilinear': [],
    'CPU Cubic': [],
    'GPU Cubic': [],
    'CPU Kriging': [],
    'GPU Kriging': []
}

for interp in interp_types:
    for machine in machines:
        key_string = machine + " " + interp
        # 1) Get all entries for machine and interpolation type from larger set
        subset = kerguelen001.loc[(kerguelen001['Machine'] == machine) & (kerguelen001['InterpolationType'] == interp)]
        
        # 2) Sum over all times and divide by length to get average
        average = np.mean(subset['Time'].values)

        perf[key_string].append(average)

        # 3) Average out the Mean Absolute Error (MAE's)
        mae_avg = np.mean(subset['MAE'].values)

        perf[key_string].append(mae_avg)

        # 4) Average out the Root Mean Squared Error (RMSE's)
        rmse_avg = np.mean(subset['RMSE'].values)

        perf[key_string].append(rmse_avg)

        # 5) Average out the max error's
        max_err_avg = np.mean(subset['Max Error'].values)

        perf[key_string].append(max_err_avg)

for key in perf.keys():
    print(key, perf[key])
# Out:
# CPU Bilinear [9.0, 6.6799, 15.5192, 351.0]
# GPU Bilinear [22.5, 6.6799, 15.5192, 351.0]
# CPU Cubic [139.5, 6.27658, 14.825, 473.25]
# GPU Cubic [83.5, 6.27658, 14.825, 473.25]
# CPU Kriging [154.0, 5.03055, 11.3488, 304.221]
# GPU Kriging [75.5, 5.03055, 11.3488, 304.221]

# %% [markdown]
# #### Removal Fraction = 0.05
# TestingResults1 - rows 338-349

# %%
# indexes are a bit off, go low-row-index - 2 and high-row-index - 1
kerguelen005 = results.iloc[336:348]
kerguelen005
# Out:
#     Machine InterpolationType GridType  BatchSize  Time  RemovalFraction  \
# 336     CPU          Bilinear        B     250344    45             0.05
# 337     CPU             Cubic        B     250344   661             0.05
# 338     CPU           Kriging        B     250344   703             0.05
# 339     GPU          Bilinear        B     250344    82             0.05
# 340     GPU             Cubic        B     250344   246             0.05
# 341     GPU           Kriging        B     250344   359             0.05
# 342     CPU          Bilinear        B     250344    47             0.05
# 343     CPU             Cubic        B     250344   645             0.05
# 344     CPU           Kriging        B     250344   708             0.05
# 345     GPU          Bilinear        B     250344    61             0.05
# 346     GPU             Cubic        B     250344   246             0.05
# 347     GPU           Kriging        B     250344   358             0.05
#
#          MAE     RMSE  Max Error
# 336  6.74368  15.9349    414.333
# 337  6.30093  15.0715    529.750
# 338  4.98024  11.2783    342.524
# 339  6.74368  15.9349    414.333
# 340  6.30093  15.0715    529.750
# 341  4.98024  11.2783    342.524
# 342  6.74368  15.9349    414.333
# 343  6.30093  15.0715    529.750
# 344  4.98024  11.2783    342.524
# 345  6.74368  15.9349    414.333
# 346  6.30093  15.0715    529.750
# 347  4.98024  11.2783    342.524

# %%
interp_types = ['Bilinear', 'Cubic', 'Kriging']
machines = ['CPU', 'GPU']

perf = {
    'CPU Bilinear': [],
    'GPU Bilinear': [],
    'CPU Cubic': [],
    'GPU Cubic': [],
    'CPU Kriging': [],
    'GPU Kriging': []
}

for interp in interp_types:
    for machine in machines:
        key_string = machine + " " + interp
        # 1) Get all entries for machine and interpolation type from larger set
        subset = kerguelen005.loc[(kerguelen005['Machine'] == machine) & (kerguelen005['InterpolationType'] == interp)]
        
        # 2) Sum over all times and divide by length to get average
        average = np.mean(subset['Time'].values)

        perf[key_string].append(average)

        # 3) Average out the Mean Absolute Error (MAE's)
        mae_avg = np.mean(subset['MAE'].values)

        perf[key_string].append(mae_avg)

        # 4) Average out the Root Mean Squared Error (RMSE's)
        rmse_avg = np.mean(subset['RMSE'].values)

        perf[key_string].append(rmse_avg)

        # 5) Average out the max error's
        max_err_avg = np.mean(subset['Max Error'].values)

        perf[key_string].append(max_err_avg)

for key in perf.keys():
    print(key, perf[key])
# Out:
# CPU Bilinear [46.0, 6.74368, 15.9349, 414.333]
# GPU Bilinear [71.5, 6.74368, 15.9349, 414.333]
# CPU Cubic [653.0, 6.30093, 15.0715, 529.75]
# GPU Cubic [246.0, 6.30093, 15.0715, 529.75]
# CPU Kriging [705.5, 4.98024, 11.2783, 342.524]
# GPU Kriging [358.5, 4.98024, 11.2783, 342.524]

# %% [markdown]
# #### Removal Fraction = 0.10
# TestingResults1 - rows 368-385

# %%
# indexes are a bit off, go low-row-index - 2 and high-row-index - 1
kerguelen010 = results.iloc[366:384]
kerguelen010
# Out:
#     Machine InterpolationType GridType  BatchSize  Time  RemovalFraction  \
# 366     CPU          Bilinear        B     500688    96              0.1
# 367     CPU             Cubic        B     500688  1355              0.1
# 368     CPU           Kriging        B     500688  1555              0.1
# 369     GPU          Bilinear        B     500688   120              0.1
# 370     GPU             Cubic        B     500688   485              0.1
# 371     GPU           Kriging        B     500688   788              0.1
# 372     CPU          Bilinear        B     500688    97              0.1
# 373     CPU             Cubic        B     500688  1382              0.1
# 374     CPU           Kriging        B     500688  1589              0.1
# 375     GPU          Bilinear        B     500688   113              0.1
# 376     GPU             Cubic        B     500688   451              0.1
# 377     GPU           Kriging        B     500688   726              0.1
# 378     CPU          Bilinear        B     500688    92              0.1
# 379     CPU             Cubic        B     500688  1373              0.1
# 380     CPU           Kriging        B     500688  1527              0.1
# 381     GPU          Bilinear        B     500688   110              0.1
# 382     GPU             Cubic        B     500688   450              0.1
# 383     GPU           Kriging        B     500688   729              0.1
#
#          MAE     RMSE  Max Error
# 366  6.76993  16.0945    493.000
# 367  6.29409  15.0865    509.000
# 368  4.86911  11.0187    342.524
# 369  6.76993  16.0945    493.000
# 370  6.29409  15.0865    509.000
# 371  4.86911  11.0187    342.524
# 372  6.76993  16.0945    493.000
# 373  6.29409  15.0865    509.000
# 374  4.86911  11.0187    342.524
# 375  6.76993  16.0945    493.000
# 376  6.29409  15.0865    509.000
# 377  4.86911  11.0187    342.524
# 378  6.76993  16.0945    493.000
# 379  6.29409  15.0865    509.000
# 380  4.86911  11.0187    342.524
# 381  6.76993  16.0945    493.000
# 382  6.29409  15.0865    509.000
# 383  4.86911  11.0187    342.524

# %%
interp_types = ['Bilinear', 'Cubic', 'Kriging']
machines = ['CPU', 'GPU']

perf = {
    'CPU Bilinear': [],
    'GPU Bilinear': [],
    'CPU Cubic': [],
    'GPU Cubic': [],
    'CPU Kriging': [],
    'GPU Kriging': []
}

for interp in interp_types:
    for machine in machines:
        key_string = machine + " " + interp
        # 1) Get all entries for machine and interpolation type from larger set
        subset = kerguelen010.loc[(kerguelen010['Machine'] == machine) & (kerguelen010['InterpolationType'] == interp)]
        
        # 2) Sum over all times and divide by length to get average
        average = np.mean(subset['Time'].values)

        perf[key_string].append(average)

        # 3) Average out the Mean Absolute Error (MAE's)
        mae_avg = np.mean(subset['MAE'].values)

        perf[key_string].append(mae_avg)

        # 4) Average out the Root Mean Squared Error (RMSE's)
        rmse_avg = np.mean(subset['RMSE'].values)

        perf[key_string].append(rmse_avg)

        # 5) Average out the max error's
        max_err_avg = np.mean(subset['Max Error'].values)

        perf[key_string].append(max_err_avg)

for key in perf.keys():
    print(key, perf[key])
# Out:
# CPU Bilinear [95.0, 6.76993, 16.0945, 493.0]
# GPU Bilinear [114.33333333333333, 6.76993, 16.0945, 493.0]
# CPU Cubic [1370.0, 6.29409, 15.0865, 509.0]
# GPU Cubic [462.0, 6.29409, 15.0865, 509.0]
# CPU Kriging [1557.0, 4.86911, 11.0187, 342.52400000000006]
# GPU Kriging [747.6666666666666, 4.86911, 11.0187, 342.52400000000006]
